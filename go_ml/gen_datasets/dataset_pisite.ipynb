# %%
import proteinshake
from proteinshake.datasets import ProteinProteinInterfaceDataset
dataset = ProteinProteinInterfaceDataset()

# %%
[s for s in dir(dataset) if not s[:2] == '__']
# Out:
# ['_interfaces',
#  'add_protein_attributes',
#  'additional_files',
#  'chain_split',
#  'check_sequence',
#  'check_signature',
#  'check_signature_same_as_hosted',
#  'compute_signature',
#  'cutoff',
#  'default_signature',
#  'describe',
#  'download',
#  'download_complete',
#  'download_precomputed',
#  'exclude_ids',
#  'exlude_args_from_signature',
#  'get_complexes_files',
#  'get_contacts',
#  'get_id_from_filename',
#  'get_raw_files',
#  'limit',
#  'maximum_length',
#  'minimum_length',
#  'n_jobs',
#  'name',
#  'only_single_chain',
#  'parse',
#  'parse_interfaces',
#  'parse_pdb',
#  'pdb2df',
#  'precomputed_already_downloaded',
#  'precomputed_available',
#  'proteins',
#  'release',
#  'repository_url',
#  'root',
#  'signature',
#  'skip_signature_check',
#  'start_download',
#  'to_graph',
#  'to_point',
#  'to_voxel',
#  'use_precomputed',
#  'validate',
#  'verbosity',
#  'version']
